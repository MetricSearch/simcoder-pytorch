# %% [markdown]
# Find the most highly categorised data in the dataset

# %%
import sys
# !{sys.executable} -m pip install torch torchvision scipy matplotlib | grep -v 'already satisfied'

# %%
from scipy.io import loadmat
import numpy as np
import pathlib

# nasty import hack - this is a code smell, work out how to remove it
import sys
sys.path.append('../')

# %%
# Download ImageNet labels

! if [ -f "imagenet_classes.txt" ]; then echo "File imagenet_classes.txt already exists"; else wget https://raw.githubusercontent.com/pytorch/hub/master/imagenet_classes.txt 2> /dev/null; fi
# Out:
# File imagenet_classes.txt already exists

# %%
# Read the categories
with open("imagenet_classes.txt", "r") as f:
    categories = [s.strip() for s in f.readlines()]

# %%
from pathlib import Path
# Load the softmax encodings of the data

from simcoder.similarity import load_mf_encodings

smData = load_mf_encodings(Path('/Volumes/Data/mf_resnet50_softmax'))

# Load the data

allData = load_mf_encodings(Path("/Volumes/Data/mf_dino2")) # load encodings

# %%
from simcoder.count_cats import find_cats_with_count_more_than_less_than,count_number_in_cat_gt_thresh

threshold = 0.90

range_catsx,counts = find_cats_with_count_more_than_less_than
(100,
                184,smData,threshold)

print( f"found {range_catsx.size} results")
for i in range(range_catsx.size):
    print( range_catsx[i], counts[i], categories[range_catsx[i]], count_number_in_cat_gt_thresh(range_catsx[i],threshold,smData) )
# Out:
# found 100 results
# 9 124 ostrich 124
# 12 143 house finch 143
# 15 110 robin 110
# 31 106 tree frog 106
# 131 109 little blue heron 109
# 145 125 king penguin 125
# 146 147 albatross 147
# 148 121 killer whale 121
# 150 122 sea lion 122
# 151 134 Chihuahua 134
# 207 124 golden retriever 124
# 292 144 tiger 144
# 310 132 ant 132
# 315 142 mantis 142
# 320 120 damselfly 120
# 324 144 cabbage butterfly 144
# 327 102 starfish 102
# 348 133 ram 133
# 354 136 Arabian camel 136
# 366 136 gorilla 136
# 401 137 accordion 137
# 402 154 acoustic guitar 154
# 406 122 altar 122
# 424 135 barbershop 135
# 433 101 bathing cap 101
# 441 157 beer glass 157
# 442 111 bell cote 111
# 447 105 binoculars 105
# 448 109 birdhouse 109
# 452 165 bonnet 165
# 455 165 bottlecap 165
# 457 120 bow tie 120
# 460 132 breakwater 132
# 466 114 bullet train 114
# 475 174 car mirror 174
# 476 159 carousel 159
# 488 119 chain 119
# 510 103 container ship 103
# 515 113 cowboy hat 113
# 536 183 dock 183
# ...

# %%
from matplotlib import pyplot as plt

def imShow( image ):
    # plt.title(Image title")
    #plt.xlabel("X pixel scaling")
    # plt.ylabel("Y pixels scaling")

    fig = plt.figure(figsize = (1,1)) # in inches!
    plt.axis('off')
    plt.imshow(image) # figsize=(640/80,640/80), dpi=80)
    plt.show()

# %%
from simcoder.count_cats import get_best_cat_index
from simcoder.similarity import get_mf_image

nth_query = 1

for i in range(range_catsx.size):
    cat_index = range_catsx[i]
    cat_name = categories[range_catsx[i]]
    ordered_queries = get_best_cat_index(cat_index,smData)
    q = ordered_queries[nth_query]
    print( cat_index,cat_name,q,":")
    imShow( get_mf_image(q) )
# Out:
# 9 ostrich 809435 :
# 12 house finch 654009 :
# 15 robin 262167 :
# 31 tree frog 987065 :
# 131 little blue heron 492398 :
# 145 king penguin 991182 :
# 146 albatross 353892 :
# 148 killer whale 815810 :
# 150 sea lion 39776 :
# 151 Chihuahua 69876 :
# 207 golden retriever 393314 :
# 292 tiger 649435 :
# 310 ant 485794 :
# 315 mantis 450674 :
# 320 damselfly 644161 :
# 324 cabbage butterfly 690659 :
# 327 starfish 833109 :
# 348 ram 617611 :
# 354 Arabian camel 68872 :
# 366 gorilla 460229 :
# 401 accordion 551808 :
# 402 acoustic guitar 303446 :
# 406 altar 388294 :
# 424 barbershop 604589 :
# 433 bathing cap 782333 :
# 441 beer glass 91563 :
# 442 bell cote 990489 :
# 447 binoculars 735902 :
# 448 birdhouse 377279 :
# 452 bonnet 136164 :
# 455 bottlecap 788049 :
# 457 bow tie 276107 :
# 460 breakwater 744238 :
# 466 bullet train 993822 :
# 475 car mirror 243233 :
# 476 carousel 407785 :
# 488 chain 732407 :
# 510 container ship 862433 :
# 515 cowboy hat 116181 :
# 536 dock 651161 :
# ...

# %%
for i in range(range_catsx.size):
    cat_index = range_catsx[i]
    cat_name = categories[range_catsx[i]]
    print( cat_index,cat_name)
# Out:
# 9 ostrich
# 12 house finch
# 15 robin
# 31 tree frog
# 131 little blue heron
# 145 king penguin
# 146 albatross
# 148 killer whale
# 150 sea lion
# 151 Chihuahua
# 207 golden retriever
# 292 tiger
# 310 ant
# 315 mantis
# 320 damselfly
# 324 cabbage butterfly
# 327 starfish
# 348 ram
# 354 Arabian camel
# 366 gorilla
# 401 accordion
# 402 acoustic guitar
# 406 altar
# 424 barbershop
# 433 bathing cap
# 441 beer glass
# 442 bell cote
# 447 binoculars
# 448 birdhouse
# 452 bonnet
# 455 bottlecap
# 457 bow tie
# 460 breakwater
# 466 bullet train
# 475 car mirror
# 476 carousel
# 488 chain
# 510 container ship
# 515 cowboy hat
# 536 dock
# 546 electric guitar
# 555 fire engine
# 568 fur coat
# 603 horse cart
# 605 iPod
# 608 jean
# 615 knee pad
# 616 knot
# 629 lipstick
# 637 mailbox
# 640 manhole cover
# 644 matchstick
# 655 miniskirt
# 661 Model T
# 671 mountain bike
# 679 necklace
# 687 organ
# 695 padlock
# 701 parachute
# 705 passenger car
# 708 pedestal
# 715 pickelhaube
# ...

# %%
# some hand picked indexes that look like the categories - use the lowest index in the category...

pick_indeces = np.ones(1000,dtype=int) # by default use the first.

pick_indeces[406] = 2 # altar
pick_indeces[433] = 2 # bathing cap
pick_indeces[447] = 2 # binoculars
pick_indeces[425] = 2 # bonnet
pick_indeces[457] = 2 # bow tie
pick_indeces[460] = 2 # breakwater
pick_indeces[615] = 2 # knee pad
pick_indeces[644] = 2 # matchstick
pick_indeces[671] = 2 # mountain bike
pick_indeces[679] = 2 # necklace
pick_indeces[724] = 2 # pirate
pick_indeces[733] = 2 # pole
pick_indeces[781] = 2 # scoreboard
pick_indeces[791] = 2 # shopping cart
pick_indeces[795] = 2 # ski
pick_indeces[865] = 2 # toyshop
pick_indeces[937] = 2 # broccoli
pick_indeces[974] = 2 # geyser

pick_indeces[424] = 3 # barbershop
pick_indeces[708] = 3 # pedestal
pick_indeces[715] = 3 # pickelhaube
pick_indeces[716] = 3 # picket fence
pick_indeces[746] = 3 # puck
pick_indeces[904] = 3 # window screen

# %%
# generate some tuned queries

selected_queries = []

for i in range(range_catsx.size):
    cat_index = range_catsx[i]
    cat_name = categories[range_catsx[i]]
    ordered_queries = get_best_cat_index(cat_index,smData)
    q = ordered_queries[pick_indeces[cat_index]]
    print( cat_index,cat_name,q,":")
    selected_queries.append(q)
    imShow( get_mf_image(q) )
# Out:
# 9 ostrich 809435 :
# 12 house finch 654009 :
# 15 robin 262167 :
# 31 tree frog 987065 :
# 131 little blue heron 492398 :
# 145 king penguin 991182 :
# 146 albatross 353892 :
# 148 killer whale 815810 :
# 150 sea lion 39776 :
# 151 Chihuahua 69876 :
# 207 golden retriever 393314 :
# 292 tiger 649435 :
# 310 ant 485794 :
# 315 mantis 450674 :
# 320 damselfly 644161 :
# 324 cabbage butterfly 690659 :
# 327 starfish 833109 :
# 348 ram 617611 :
# 354 Arabian camel 68872 :
# 366 gorilla 460229 :
# 401 accordion 551808 :
# 402 acoustic guitar 303446 :
# 406 altar 82318 :
# 424 barbershop 264603 :
# 433 bathing cap 804432 :
# 441 beer glass 91563 :
# 442 bell cote 990489 :
# 447 binoculars 760924 :
# 448 birdhouse 377279 :
# 452 bonnet 136164 :
# 455 bottlecap 788049 :
# 457 bow tie 276490 :
# 460 breakwater 274725 :
# 466 bullet train 993822 :
# 475 car mirror 243233 :
# 476 carousel 407785 :
# 488 chain 732407 :
# 510 container ship 862433 :
# 515 cowboy hat 116181 :
# 536 dock 651161 :
# ...

# %%
with open( "selected_queries.txt","w" ) as f:
    for q in selected_queries:
        f.write( f"{q}\n" )

# %%
from simcoder.count_cats import get_topcat

q0 = 21711

tc = get_topcat(q0,smData)
print( tc, categories[tc] )
# Out:
# 679 necklace

# %%
from simcoder.similarity import euclid as euclid

def getDists(query_index,allData):
    '''Return the distances from the query to allData'''
    '''Returns an array same dimension as allData of scalars'''
    mf_query_data = allData[query_index]
    distances = euclid(mf_query_data, allData)
    return distances

# %%
from simcoder.similarity import get_mf_image


get_mf_image(q0)
# Out:
# <PIL.Image.Image image mode=RGB size=500x333>

# %%
dists = getDists(q0,allData)
closest_indices = np.argsort(dists) # the closest images to the query

best_100_for_one = closest_indices[0:100]

# %%
from simcoder.similarity import make_mf_image_grid

make_mf_image_grid(best_100_for_one,10,10,50,50)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>

# %%
count = 0
tot_cats = 0
for i in range(100):
    cc = get_topcat(best_100_for_one[i],smData)
    if tc == cc:
        count += 1
    tot_cats += smData[best_100_for_one[i],tc]

    print( categories[cc] )

print(count ,tot_cats )
# Out:
# necklace
# strawberry
# washer
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# strawberry
# trifle
# strawberry
# strawberry
# strawberry
# broccoli
# strawberry
# strawberry
# strawberry
# ...

# %%
from simcoder.count_cats import count_images_in_category


vals,counts =count_images_in_category(smData)

# %%
print( categories[vals[1]], vals[1], counts[1] )
# Out:
# goldfish 1 1037
