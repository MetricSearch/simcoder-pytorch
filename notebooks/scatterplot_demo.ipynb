# %% [markdown]
# ## Program to plot 2D Scatter plots using distances.

# %%
from pathlib import Path
from sisap2023.utils.mirflickr import load_encodings

data_root = Path("/Volumes/Data")

# load the dino2 image embeddings
data = load_encodings(data_root / "mf_dino2")

# %%
from sisap2023.utils.scatter import make2Dscatter

data_to_plot = data[2:103]

plot = make2Dscatter(data[0],data[1],data_to_plot)
plot.show()
plot = make2Dscatter(data[1007],data[1444],data_to_plot)
plot.show()
plot = make2Dscatter(data[2050],data[1004],data_to_plot)
plot.show()
